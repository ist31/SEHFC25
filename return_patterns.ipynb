# %%
import pandas as pd
import eikon as ek

ek.set_app_key('cf65edd17ba64c9b860bcc826cdbf5366ca0ec93')

# Define the RIC and fields
ric = 'PG'
fields = ['TR.RevenueActReportDate']

# Fetch the data
df, err = ek.get_data(ric, fields, {'SDate': '2019-01-01', 'EDate': '2020-01-01'})

# Check for errors
if err:
    print(f"Error: {err}")
else:
    # Adjust pandas display settings
    pd.set_option('display.max_rows', None)  # Show all rows
    pd.set_option('display.max_columns', None)  # Show all columns
    print(df)
# Out:
#     Instrument           Report Date
# 0           PG  2018-07-31T07:00:00Z
# 1           PG  2018-07-31T07:00:00Z
# 2           PG  2018-07-31T07:00:00Z
# 3           PG  2018-07-31T07:00:00Z
# 4           PG  2018-07-31T07:00:00Z
# 5           PG  2018-07-31T07:00:00Z
# 6           PG  2018-07-31T07:00:00Z
# 7           PG  2018-07-31T07:00:00Z
# 8           PG  2018-07-31T07:00:00Z
# 9           PG  2018-07-31T07:00:00Z
# 10          PG  2018-07-31T07:00:00Z
# 11          PG  2018-07-31T07:00:00Z
# 12          PG  2018-07-31T07:00:00Z
# 13          PG  2018-07-31T07:00:00Z
# 14          PG  2018-07-31T07:00:00Z
# 15          PG  2018-07-31T07:00:00Z
# 16          PG  2018-07-31T07:00:00Z
# 17          PG  2018-07-31T07:00:00Z
# 18          PG  2018-07-31T07:00:00Z
# 19          PG  2018-07-31T07:00:00Z
# 20          PG  2018-07-31T07:00:00Z
# 21          PG  2018-07-31T07:00:00Z
# 22          PG  2018-07-31T07:00:00Z
# 23          PG  2018-07-31T07:00:00Z
# ...
